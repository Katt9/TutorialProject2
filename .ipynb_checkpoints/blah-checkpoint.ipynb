# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('postgresql+psycopg2://aadadey:@localhost/susb')
connection = engine.connect()
result = connection.execute("select * from susb_2016")
for row in result:
    print(row)
    break
# Out:
# ('00', '--', '01', 5954684, 7757807, 126752238, '', 'G', 2140174759, 'G', 'United States', 'Total', '01:  Total')

# %%
dbdf = pd.read_sql_query("select * from susb_2016 where state = '10'", connection)
dbdf
# Out:
#       state   naics entrsize  firm  estb  empl empfl_r emplf_n    payr  \
# 0        10   71212       01     4     4    40               G     811
# 1        10  453920       05    14    14    28               G    1706
# 2        10  453920       08    14    14    28               G    1706
# 3        10    6212       05   224   226  1835               G  120639
# 4        10   71211       08    24    25   712               G   20158
# ...     ...     ...      ...   ...   ...   ...     ...     ...     ...
# 11117    10  441310       01    50   108  1060               G   29397
# 11118    10  441310       02    21    21    41               H    1153
# 11119    10  441310       03    14    14    97               J    3001
# 11120    10  441310       04     3     3    44               H    1276
# 11121    10  441310       05    38    38   182               H    5430
#
#       payrfl_n statedscr                                naicsdscr entrsizedscr
# 0            H  Delaware                         Historical Sites   01:  Total
# 1            H  Delaware                              Art Dealers     05:  <20
# 2            H  Delaware                              Art Dealers    08:  <500
# 3            G  Delaware                      Offices of Dentists     05:  <20
# 4            G  Delaware                                  Museums    08:  <500
# ...        ...       ...                                      ...          ...
# 11117        G  Delaware  Automotive Parts and Accessories Stores   01:  Total
# 11118        G  Delaware  Automotive Parts and Accessories Stores     02:  0-4
# 11119        H  Delaware  Automotive Parts and Accessories Stores     03:  5-9
# 11120        H  Delaware  Automotive Parts and Accessories Stores   04:  10-19
# 11121        H  Delaware  Automotive Parts and Accessories Stores     05:  <20
#
# [11122 rows x 13 columns]

# %%
df = pd.read_csv('us_state_6digitnaics_2016.txt', encoding='ISO-8859-1')

# %%
df
# Out:
#         STATE NAICS  ENTRSIZE     FIRM     ESTB     EMPL_N EMPLFL_R EMPLFL_N  \
# 0           0    --         1  5954684  7757807  126752238      NaN        G
# 1           0    --         2  3665182  3671901    5923452      NaN        G
# 2           0    --         3  1013878  1025690    6681968      NaN        G
# 3           0    --         4   626900   657781    8432521      NaN        G
# 4           0    --         5  5305960  5355372   21037941      NaN        G
# ...       ...   ...       ...      ...      ...        ...      ...      ...
# 727993     56    99         3        3        3         18      NaN        J
# 727994     56    99         4        1        1          0        A        D
# 727995     56    99         5       66       66        111      NaN        H
# 727996     56    99         6        2        2          0        B        D
# 727997     56    99         8       68       68        161      NaN        J
#
#             PAYR_N PAYRFL_N      STATEDSCR                    NCSDSCR  \
# 0       6435142055        G  United States                      Total
# 1        268039737        G  United States                      Total
# 2        248985263        G  United States                      Total
# 3        329388425        G  United States                      Total
# 4        846413425        G  United States                      Total
# ...            ...      ...            ...                        ...
# 727993         178        J        Wyoming  Industries not classified
# 727994           0        D        Wyoming  Industries not classified
# 727995        1906        G        Wyoming  Industries not classified
# 727996           0        D        Wyoming  Industries not classified
# 727997        2012        G        Wyoming  Industries not classified
#
#        entrsizedscr
# 0        01:  Total
# 1          02:  0-4
# 2          03:  5-9
# 3        04:  10-19
# 4          05:  <20
# ...             ...
# 727993     03:  5-9
# 727994   04:  10-19
# 727995     05:  <20
# 727996   06:  20-99
# 727997    08:  <500
#
# [727998 rows x 13 columns]

# %%
df[0:10].sum()
# Out:
# STATE                                                           0
# NAICS                                        ------------------11
# ENTRSIZE                                                       46
# FIRM                                                     23172143
# ESTB                                                     27321858
# EMPL_N                                                  334618045
# EMPLFL_R                                                        0
# EMPLFL_N                                               GGGGGGGGGG
# PAYR_N                                                16339763092
# PAYRFL_N                                               GGGGGGGGGG
# STATEDSCR       United StatesUnited StatesUnited StatesUnited ...
# NCSDSCR         TotalTotalTotalTotalTotalTotalTotalTotalTotalA...
# entrsizedscr    01:  Total02:  0-403:  5-904:  10-1905:  <2006...
# dtype: object

# %%
df['FIRM'].describe()['mean']
# Out:
# 388.60420220934674

# %%
df[(df['STATE'] == 10) & (df['ENTRSIZE'].isin([2, 3, 4]))]
# Out:
#         STATE   NAICS  ENTRSIZE   FIRM   ESTB  EMPL_N EMPLFL_R EMPLFL_N  \
# 117597     10      --         2  11281  11310   17696      NaN        G
# 117598     10      --         3   3002   3037   19768      NaN        G
# 117599     10      --         4   2052   2149   27137      NaN        G
# 117606     10      11         2     22     22      25      NaN        H
# 117607     10      11         3      7      7      51      NaN        J
# ...       ...     ...       ...    ...    ...     ...      ...      ...
# 128707     10  813990         2     39     39      68      NaN        G
# 128708     10  813990         3      7      7      46      NaN        J
# 128709     10  813990         4      3      3      38      NaN        J
# 128714     10      99         2     50     50      43      NaN        H
# 128715     10      99         4      2      2       0        B        D
#
#          PAYR_N PAYRFL_N STATEDSCR  \
# 117597   852281        G  Delaware
# 117598   785324        G  Delaware
# 117599  1140818        G  Delaware
# 117606      792        G  Delaware
# 117607     1651        H  Delaware
# ...         ...      ...       ...
# 128707     3007        G  Delaware
# 128708     1783        H  Delaware
# 128709      760        G  Delaware
# 128714     1233        G  Delaware
# 128715        0        D  Delaware
#
#                                                   NCSDSCR entrsizedscr
# 117597                                              Total     02:  0-4
# 117598                                              Total     03:  5-9
# 117599                                              Total   04:  10-19
# 117606         Agriculture, Forestry, Fishing and Hunting     02:  0-4
# 117607         Agriculture, Forestry, Fishing and Hunting     03:  5-9
# ...                                                   ...          ...
# 128707  Other Similar Organizations (except Business, ...     02:  0-4
# 128708  Other Similar Organizations (except Business, ...     03:  5-9
# 128709  Other Similar Organizations (except Business, ...   04:  10-19
# 128714                          Industries not classified     02:  0-4
# 128715                          Industries not classified   04:  10-19
#
# [3491 rows x 13 columns]

# %%
df[(df['STATE'] == 10) & (df['ENTRSIZE'].isin([2, 3, 4])) & (df['EMPL_N'] < 1000)]
# Out:
#         STATE   NAICS  ENTRSIZE  FIRM  ESTB  EMPL_N EMPLFL_R EMPLFL_N  PAYR_N  \
# 117606     10      11         2    22    22      25      NaN        H     792
# 117607     10      11         3     7     7      51      NaN        J    1651
# 117608     10      11         4     3     3      33      NaN        J    1835
# 117613     10     113         2     2     2       0        A        D       0
# 117614     10     113         3     2     2       0        A        D       0
# ...       ...     ...       ...   ...   ...     ...      ...      ...     ...
# 128707     10  813990         2    39    39      68      NaN        G    3007
# 128708     10  813990         3     7     7      46      NaN        J    1783
# 128709     10  813990         4     3     3      38      NaN        J     760
# 128714     10      99         2    50    50      43      NaN        H    1233
# 128715     10      99         4     2     2       0        B        D       0
#
#        PAYRFL_N STATEDSCR                                            NCSDSCR  \
# 117606        G  Delaware         Agriculture, Forestry, Fishing and Hunting
# 117607        H  Delaware         Agriculture, Forestry, Fishing and Hunting
# 117608        J  Delaware         Agriculture, Forestry, Fishing and Hunting
# 117613        D  Delaware                               Forestry and Logging
# 117614        D  Delaware                               Forestry and Logging
# ...         ...       ...                                                ...
# 128707        G  Delaware  Other Similar Organizations (except Business, ...
# 128708        H  Delaware  Other Similar Organizations (except Business, ...
# 128709        G  Delaware  Other Similar Organizations (except Business, ...
# 128714        G  Delaware                          Industries not classified
# 128715        D  Delaware                          Industries not classified
#
#        entrsizedscr
# 117606     02:  0-4
# 117607     03:  5-9
# 117608   04:  10-19
# 117613     02:  0-4
# 117614     03:  5-9
# ...             ...
# 128707     02:  0-4
# 128708     03:  5-9
# 128709   04:  10-19
# 128714     02:  0-4
# 128715   04:  10-19
#
# [3436 rows x 13 columns]

# %%
sub_df = df[(df['STATE'] == 10) & (df['ENTRSIZE'].isin([2, 3, 4])) & (df['EMPL_N'] < 1000)]
sub_df['PAYR_N'].describe()
# Out:
# count     3436.000000
# mean      2604.029104
# std       6205.496423
# min          0.000000
# 25%          0.000000
# 50%        543.500000
# 75%       2243.000000
# max      66559.000000
# Name: PAYR_N, dtype: float64
